# %%
# !pip install folium==0.13.0

# %%
import requests as rq
import json
import pandas as pd
import numpy as np
import folium
import os
from folium import plugins

# %%
# 경로 이동.
os.getcwd()

# %%
#서울시 공영주차장 안내 정보.csv 다운받기

# %%
df = pd.read_csv(r'./data/서울시 공영주차장 안내 정보.csv', encoding='cp949')

# %%
df.columns
# Out:
# Index(['주차장코드', '주차장명', '주소', '주차장 종류', '주차장 종류명', '운영구분', '운영구분명', '전화번호',
#        '주차현황 정보 제공여부', '주차현황 정보 제공여부명', '총 주자면', '유무료구분', '유무료구분명', '야간무료개방여부',
#        '야간무료개방여부명', '평일 운영 시작시각(HHMM)', '평일 운영 종료시각(HHMM)', '주말 운영 시작시각(HHMM)',
#        '주말 운영 종료시각(HHMM)', '공휴일 운영 시작시각(HHMM)', '공휴일 운영 종료시각(HHMM)',
#        '최종데이터 동기화 시간', '토요일 유,무료 구분', '토요일 유,무료 구분명', '공휴일 유,무료 구분',
#        '공휴일 유,무료 구분명', '월 정기권 금액', '노상 주차장 관리그룹번호', '기본 주차 요금',
#        '기본 주차 시간(분 단위)', '추가 단위 요금', '추가 단위 시간(분 단위)', '버스 기본 주차 요금',
#        '버스 기본 주차 시간(분 단위)', '버스 추가 단위 시간(분 단위)', '버스 추가 단위 요금', '일 최대 요금',
#        '위도', '경도'],
#       dtype='object')

# %%
my_df = df

# %%
df
# Out:
#         주차장코드              주차장명                주소 주차장 종류 주차장 종류명  운영구분  \
# 0     1010089     초안산근린공원주차장(구)       도봉구 창동 24-0     NW  노외 주차장     1
# 1     1012254   마들스타디움(근린공원)(구)     노원구 상계동 770-2     NW  노외 주차장     1
# 2     1013181  마장동(건물) 공영주차장(구)     성동구 마장동 463-2     NW  노외 주차장     1
# 3     1025695       영등포여고 공영(구)    영등포구 신길동 184-3     NW  노외 주차장     1
# 4     1025696      당산근린공원 공영(구)  영등포구 당산동3가 385-0     NW  노외 주차장     1
# ...       ...               ...               ...    ...     ...   ...
# 8512   968503  삼양마을공원지하공영주차장(구)     강북구 미아동 748-2     NW  노외 주차장     1
# 8513   968514     색동공원 공영주차장(구)      강북구 수유동 49-7     NW  노외 주차장     1
# 8514   980509          비봉주차장(구)     종로구 구기동 139-9     NW  노외 주차장     1
# 8515   984617      신도림역환승주차장(구)       구로구 구로동 1-4     NW  노외 주차장     1
# 8516   984688   구로아트밸리 지하주차장(구)     구로구 구로동 102-0     NW  노외 주차장     1
#
#         운영구분명          전화번호  주차현황 정보 제공여부                  주차현황 정보 제공여부명  ...  \
# ...

# %%
df = df[['주차장명', '주소', '주차장 종류명', '운영구분명', '위도', '경도']]

# %%
df
# Out:
#                   주차장명                주소 주차장 종류명    운영구분명         위도  \
# 0        초안산근린공원주차장(구)       도봉구 창동 24-0  노외 주차장  시간제 주차장        NaN
# 1      마들스타디움(근린공원)(구)     노원구 상계동 770-2  노외 주차장  시간제 주차장        NaN
# 2     마장동(건물) 공영주차장(구)     성동구 마장동 463-2  노외 주차장  시간제 주차장        NaN
# 3          영등포여고 공영(구)    영등포구 신길동 184-3  노외 주차장  시간제 주차장  37.515205
# 4         당산근린공원 공영(구)  영등포구 당산동3가 385-0  노외 주차장  시간제 주차장        NaN
# ...                ...               ...     ...      ...        ...
# 8512  삼양마을공원지하공영주차장(구)     강북구 미아동 748-2  노외 주차장  시간제 주차장        NaN
# 8513     색동공원 공영주차장(구)      강북구 수유동 49-7  노외 주차장  시간제 주차장        NaN
# 8514          비봉주차장(구)     종로구 구기동 139-9  노외 주차장  시간제 주차장        NaN
# 8515      신도림역환승주차장(구)       구로구 구로동 1-4  노외 주차장  시간제 주차장        NaN
# 8516   구로아트밸리 지하주차장(구)     구로구 구로동 102-0  노외 주차장  시간제 주차장        NaN
#
#               경도
# 0            NaN
# 1            NaN
# 2            NaN
# 3     126.915116
# 4            NaN
# ...          ...
# ...

# %%
missing_counts = df[['위도', '경도']].isnull().sum()
print(missing_counts)
# Out:
# 위도    1742
# 경도    1742
# dtype: int64

# %%
total_counts = df[['위도', '경도']].count()
print(total_counts)
# Out:
# 위도    6775
# 경도    6775
# dtype: int64

# %%
# 결측치 비율 계산하기
missing_ratio = missing_counts / total_counts
print(missing_ratio*100)
# Out:
# 위도    25.712177
# 경도    25.712177
# dtype: float64

# %%
park_type = df[['운영구분명']]
park_type.drop_duplicates()
# Out:
#                운영구분명
# 0            시간제 주차장
# 6      시간제 + 거주자 주차장
# 212         버스전용 주차장
# 693       이륜차 전용 주차장
# 1120      거주자 우선 주차장
# 6410  시간제 + 버스전용 주차장

# %%
df = df[(df.운영구분명 != '버스전용 주차장') & (df.운영구분명 != '이륜차 전용 주차장')]

# %%
df #버스전용 주차장, 이륜차 전용 주차장 제거
# Out:
#                   주차장명                주소 주차장 종류명    운영구분명         위도  \
# 0        초안산근린공원주차장(구)       도봉구 창동 24-0  노외 주차장  시간제 주차장        NaN
# 1      마들스타디움(근린공원)(구)     노원구 상계동 770-2  노외 주차장  시간제 주차장        NaN
# 2     마장동(건물) 공영주차장(구)     성동구 마장동 463-2  노외 주차장  시간제 주차장        NaN
# 3          영등포여고 공영(구)    영등포구 신길동 184-3  노외 주차장  시간제 주차장  37.515205
# 4         당산근린공원 공영(구)  영등포구 당산동3가 385-0  노외 주차장  시간제 주차장        NaN
# ...                ...               ...     ...      ...        ...
# 8512  삼양마을공원지하공영주차장(구)     강북구 미아동 748-2  노외 주차장  시간제 주차장        NaN
# 8513     색동공원 공영주차장(구)      강북구 수유동 49-7  노외 주차장  시간제 주차장        NaN
# 8514          비봉주차장(구)     종로구 구기동 139-9  노외 주차장  시간제 주차장        NaN
# 8515      신도림역환승주차장(구)       구로구 구로동 1-4  노외 주차장  시간제 주차장        NaN
# 8516   구로아트밸리 지하주차장(구)     구로구 구로동 102-0  노외 주차장  시간제 주차장        NaN
#
#               경도
# 0            NaN
# 1            NaN
# 2            NaN
# 3     126.915116
# 4            NaN
# ...          ...
# ...

# %%
# 주소가 중복인 값들을 제거
df = df.drop_duplicates(subset = ['주소'])

# %%
park_isnull = df[pd.isnull(df.위도) & pd.isnull(df.경도)] #결측치 있는 주소들만 모아서 park_isnull에 저장
park_isnull = park_isnull[['주차장명', '주소', '위도', '경도']]

# %%
print(park_isnull)
print(park_isnull.count())
# Out:
#                    주차장명                주소  위도  경도
# 0         초안산근린공원주차장(구)       도봉구 창동 24-0 NaN NaN
# 1       마들스타디움(근린공원)(구)     노원구 상계동 770-2 NaN NaN
# 2      마장동(건물) 공영주차장(구)     성동구 마장동 463-2 NaN NaN
# 4          당산근린공원 공영(구)  영등포구 당산동3가 385-0 NaN NaN
# 5              대림운동장(구)    영등포구 대림동 780-0 NaN NaN
# ...                 ...               ...  ..  ..
# 8509  구세군길 공영주차장(무인)(구)  강북구 미아동 791-1360 NaN NaN
# 8511     삼양시장길 공영주차장(구)  강북구 미아동 791-1429 NaN NaN
# 8512   삼양마을공원지하공영주차장(구)     강북구 미아동 748-2 NaN NaN
# 8515       신도림역환승주차장(구)       구로구 구로동 1-4 NaN NaN
# 8516    구로아트밸리 지하주차장(구)     구로구 구로동 102-0 NaN NaN
#
# [1172 rows x 4 columns]
# 주차장명    1172
# 주소      1172
# 위도         0
# 경도         0
# dtype: int64

# %%
#위도, 경도가 없는 것들은 주소를 기준으로 위도, 경도 구하기 (google map 활용)

# %%
google_api_key = ''
# url = 'https://maps.googleapis.com/maps/api/geocode/outputFormat?parameters'

# %%
def get_latitude_longitude(address): # 주소를 가지고 위도, 경도를 알아내기
    url = f'https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={google_api_key}'
    response = response = rq.get(url)
    if response.status_code == 200:
        results = response.json()
        if results['status'] == 'OK': #results status가 OK인지 확인
            latitude = results['results'][0]['geometry']['location']['lat']
            longitude = results['results'][0]['geometry']['location']['lng']
            return latitude, longitude
    return None, None

# %%
#(위도,경도)에 함수를 적용하기
for index, row in park_isnull.iterrows(): 
    latitude, longitude = get_latitude_longitude(row['주소'])
    #park_isnull의 주소를 위도, 경도로 바꿔서 df에 적용
    df.at[index, '위도'] = latitude
    df.at[index, '경도'] = longitude
print(df)
# Out:
#                   주차장명                주소 주차장 종류명    운영구분명         위도  \
# 0        초안산근린공원주차장(구)       도봉구 창동 24-0  노외 주차장  시간제 주차장  37.653383
# 1      마들스타디움(근린공원)(구)     노원구 상계동 770-2  노외 주차장  시간제 주차장  37.644160
# 2     마장동(건물) 공영주차장(구)     성동구 마장동 463-2  노외 주차장  시간제 주차장  37.569939
# 3          영등포여고 공영(구)    영등포구 신길동 184-3  노외 주차장  시간제 주차장  37.515205
# 4         당산근린공원 공영(구)  영등포구 당산동3가 385-0  노외 주차장  시간제 주차장  37.525511
# ...                ...               ...     ...      ...        ...
# 8510      가오리 공영주차장(구)     강북구 수유동 349-3  노외 주차장  시간제 주차장  37.641607
# 8511    삼양시장길 공영주차장(구)  강북구 미아동 791-1429  노외 주차장  시간제 주차장  37.625864
# 8512  삼양마을공원지하공영주차장(구)     강북구 미아동 748-2  노외 주차장  시간제 주차장  37.622731
# 8515      신도림역환승주차장(구)       구로구 구로동 1-4  노외 주차장  시간제 주차장  37.507308
# 8516   구로아트밸리 지하주차장(구)     구로구 구로동 102-0  노외 주차장  시간제 주차장  37.496947
#
#               경도
# 0     127.051813
# 1     127.058300
# 2     127.035135
# 3     126.915116
# 4     126.895769
# ...          ...
# ...

# %%
df.isnull().sum()
# Out:
# 주차장명       0
# 주소         0
# 주차장 종류명    0
# 운영구분명      0
# 위도         0
# 경도         0
# dtype: int64

# %%
#주차장현황 dataframe을 csv파일로 저장하기
os.chdir(r'./data')
df.to_csv('parkdf.csv', index=False, encoding='cp949')

# %%
os.getcwd()

# %%
park_df = pd.read_csv(r'./data/parkdf_v2.csv', encoding='cp949')

# %%
park_df = park_df[park_df['주차장명'].str.contains('공영|공유')]
park_df
# Out:
#                    주차장명                주소 주차장 종류명          운영구분명         위도  \
# 2      마장동(건물) 공영주차장(구)     성동구 마장동 463-2  노외 주차장        시간제 주차장  37.569939
# 3           영등포여고 공영(구)    영등포구 신길동 184-3  노외 주차장        시간제 주차장  37.515205
# 4          당산근린공원 공영(구)  영등포구 당산동3가 385-0  노외 주차장        시간제 주차장  37.525511
# 6         휘경마을 공영주차장(구)   동대문구 휘경동 308-32  노외 주차장  시간제 + 거주자 주차장  37.588069
# 7            중산공영주차장(구)    동대문구 답십리동 23-3  노외 주차장  시간제 + 거주자 주차장  37.568718
# ...                 ...               ...     ...            ...        ...
# 1461         도화공영주차장(구)   동작구 상도동 244-183  노외 주차장        시간제 주차장  37.499784
# 1463  구세군길 공영주차장(무인)(구)  강북구 미아동 791-1360  노외 주차장        시간제 주차장  37.626181
# 1464       가오리 공영주차장(구)     강북구 수유동 349-3  노외 주차장        시간제 주차장  37.641607
# 1465     삼양시장길 공영주차장(구)  강북구 미아동 791-1429  노외 주차장        시간제 주차장  37.625864
# 1466   삼양마을공원지하공영주차장(구)     강북구 미아동 748-2  노외 주차장        시간제 주차장  37.622731
#
#               경도
# 2     127.035135
# 3     126.915116
# ...

# %%
park_df.to_csv(r'./data/parkdf.csv', index=False, encoding='cp949')
